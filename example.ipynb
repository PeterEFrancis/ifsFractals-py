# %% [markdown]
# # `ifsFractals` Example Notebook

# %%
from ifsFractals import *

# %%
T_0 = Translate(1/3, 0) @ ShearX(1/3) @ Scale(1/3)
T_1 = Rotate(pi/3) @ T_0
T_2 = Rotate(2*pi/3) @ T_0
T_3 = Rotate(3*pi/3) @ T_0
T_4 = Rotate(4*pi/3) @ T_0
T_5 = Rotate(5*pi/3) @ T_0

T = [T_0, T_1, T_2, T_3, T_4, T_5]

# %%
fractal = Fractal(T)

# %%
fractal.check_transformations(verbose=True)
# Out:
# The opNorm of every transformation is less than 1 so all of the transformations are contraction mappings.

# %%
fractal.plot_figures()

# %%
fractal.add_points(100_000)
fractal.display()

# %%
fractal.export()
# Out:
# [[0.3333333333333333, 0.1111111111111111, 0.3333333333333333], [0.0, 0.3333333333333333, 0.0], [0.0, 0.0, 1.0]]
# [[0.16666666666666669, -0.23311957903925729, 0.16666666666666669], [0.28867513459481287, 0.2628917115316043, 0.28867513459481287], [0.0, 0.0, 1.0]]
# [[-0.16666666666666657, -0.34423069015036845, -0.16666666666666657], [0.2886751345948129, -0.07044162180172894, 0.2886751345948129], [0.0, 0.0, 1.0]]
# [[-0.3333333333333333, -0.11111111111111115, -0.3333333333333333], [4.082155997157844e-17, -0.3333333333333333, 4.082155997157844e-17], [0.0, 0.0, 1.0]]
# [[-0.1666666666666668, 0.23311957903925717, -0.1666666666666668], [-0.28867513459481275, -0.2628917115316044, -0.28867513459481275], [0.0, 0.0, 1.0]]
# [[0.16666666666666666, 0.3442306901503684, 0.16666666666666666], [-0.28867513459481287, 0.07044162180172904, -0.28867513459481287], [0.0, 0.0, 1.0]]

# %%
fractal.embed_web()
# Out:
#         <iframe
#             width="100%"
#             height="1000px"
#             src="https://ifs-fractals.herokuapp.com/playground/t=M(0.333,0.111,0.0,0.333,0.333,0.0)&M(0.167,-0.233,0.289,0.263,0.167,0.289)&M(-0.167,-0.344,0.289,-0.07,-0.167,0.289)&M(-0.333,-0.111,0.0,-0.333,-0.333,0.0)&M(-0.167,0.233,-0.289,-0.263,-0.167,-0.289)&M(0.167,0.344,-0.289,0.07,0.167,-0.289)/w=0.16666666666666666,0.16666666666666666,0.16666666666666666,0.16666666666666666,0.16666666666666666,0.16666666666666666"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
